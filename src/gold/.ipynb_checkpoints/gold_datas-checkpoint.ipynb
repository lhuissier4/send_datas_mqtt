# %%
from pathlib import Path
from typing import Optional

import pandas as pd, numpy as np

# %%
df_simule = pd.DataFrame(pd.read_csv(r"../../datas/bronze/dataset_brut.csv"))
df_iot = pd.DataFrame(pd.read_csv(r"../../datas/silver/dataset_iot.csv"))
df_plc = pd.DataFrame(pd.read_csv(r"../../datas/silver/dataset_plc.csv"))

# %%
df_simule.head()
# Out:
#              timestamp machine_id type_machine secteur type_metal  \
# 0  2026-06-01 00:00:00    MCH-001   CNC_5_Axes    Aéro  Aluminium
# 1  2026-06-01 00:00:30    MCH-001   CNC_5_Axes    Aéro  Aluminium
# 2  2026-06-01 00:01:00    MCH-001   CNC_5_Axes    Aéro  Aluminium
# 3  2026-06-01 00:01:30    MCH-001   CNC_5_Axes    Aéro  Aluminium
# 4  2026-06-01 00:02:00    MCH-001   CNC_5_Axes    Aéro  Aluminium
#
#    vitesse_rotation_nominal  courant_moteur_nominal  \
# 0                      6000                    20.0
# 1                      6000                    20.0
# 2                      6000                    20.0
# 3                      6000                    20.0
# 4                      6000                    20.0
#
#    pression_hydraulique_nominal statut_nominal  temp_base_moteur  ...  \
# 0                           0.0     Production              40.0  ...
# 1                           0.0     Production              40.0  ...
# 2                           0.0     Production              40.0  ...
# 3                           0.0     Production              40.0  ...
# 4                           0.0     Production              40.0  ...
#
#   iot_vitesse_rotation iot_courant_moteur  iot_pression_hydraulique  \
# 0               6000.0          19.815780                  0.000000
# 1               6000.0          20.028414                  0.000000
# 2               6000.0          20.318093                  0.355548
# 3               6000.0          19.882224                  0.000000
# 4               6000.0          19.984053                  0.240067
#
#    iot_temperature  iot_vibration_rms  iot_vibration_peak  iot_charge_moteur  \
# 0        48.711109           0.856741            1.267143               45.0
# 1        48.552522           0.852020            1.355303               45.0
# 2        48.749168           0.849968            1.226547               45.0
# 3        48.968161           0.881784            1.205064               45.0
# 4        48.529023           0.837604            1.358074               45.0
#
#      age_jours  age_virtuel_jours  RUL_jours
# 0  1200.000000         840.000000   1.513542
# 1  1200.000347         840.000347   1.513194
# 2  1200.000694         840.000694   1.512847
# 3  1200.001042         840.001042   1.512500
# 4  1200.001389         840.001389   1.512153
#
# [5 rows x 22 columns]

# %%
df_iot.head()
# Out:
#              timestamp machine_id  iot_vitesse_rotation  iot_courant_moteur  \
# 0  2026-06-01 00:00:00    MCH-001                6000.0           19.815780
# 1  2026-06-01 00:00:00    MCH-002                4500.0           22.085784
# 2  2026-06-01 00:00:00    MCH-007                4800.0           16.279980
# 3  2026-06-01 00:00:00    MCH-004                1250.0           43.193466
# 4  2026-06-01 00:00:00    MCH-006                   0.0           54.966129
#
#    iot_pression_hydraulique  iot_temperature  iot_vibration_peak  \
# 0                  0.000000        48.711109            1.267143
# 1                  0.000000        40.794459            1.257802
# 2                  0.258873        39.129279            0.508685
# 3                  0.474612        56.080133            1.086669
# 4                180.021158        61.644770            3.206393
#
#    iot_charge_moteur
# 0               45.0
# 1               45.0
# 2               45.0
# 3               80.0
# 4               70.0

# %%
df_plc.head()
# Out:
#   machine_id            timestamp iot_statut_machine type_metal
# 0    MCH-001  2026-06-01 00:00:00         Production  Aluminium
# 1    MCH-002  2026-06-01 00:00:00         Production  Aluminium
# 2    MCH-007  2026-06-01 00:00:00         Production  Aluminium
# 3    MCH-004  2026-06-01 00:00:00         Production     Titane
# 4    MCH-006  2026-06-01 00:00:00         Production      Acier

# %%
df_type_machine = df_simule[[
    "type_machine"
]].drop_duplicates(subset=[
        "type_machine",
    ]
)
df_type_machine["id"] = df_type_machine["type_machine"].astype("category").cat.codes + 1
df_type_machine.head(20)
# Out:
#         type_machine  id
# 0         CNC_5_Axes   2
# 529920    CNC_3_Axes   1
# 1059840  Robot_Laser   4
# 1589760  Presse_Hydr   3

# %%
df_type_metal=df_simule[[
    "type_metal"
]].drop_duplicates(subset=[
        "type_metal",
    ]
)
df_type_metal["id"] = df_type_metal["type_metal"].astype("category").cat.codes + 1
df_type_metal.head(20)
# Out:
#         type_metal  id
# 0        Aluminium   2
# 480         Titane   4
# 14400        Aucun   3
# 1589760      Acier   1

# %%
df_plc = df_plc.merge(
    df_type_metal[["type_metal", "id"]].rename(columns={"id": "id_type_metal"}),
    on="type_metal",
    how="left"
).drop(columns="type_metal")
df_plc.head()
# Out:
#   machine_id            timestamp iot_statut_machine  id_type_metal
# 0    MCH-001  2026-06-01 00:00:00         Production              2
# 1    MCH-002  2026-06-01 00:00:00         Production              2
# 2    MCH-007  2026-06-01 00:00:00         Production              2
# 3    MCH-004  2026-06-01 00:00:00         Production              4
# 4    MCH-006  2026-06-01 00:00:00         Production              1

# %%
df_gmao_label = df_simule[[
    "label_gmao"
]].drop_duplicates(subset=[
        "label_gmao",
    ]
)
df_gmao_label["id"] = df_gmao_label["label_gmao"].astype("category").cat.codes + 1
df_gmao_label.head()
# Out:
#                      label_gmao  id
# 0                          Sain  20
# 2424                  Alerte_P4   4
# 4360   Maintenance_Correctif_P4  13
# 12200                 Alerte_P1   1
# 12844  Maintenance_Correctif_P1  10

# %%
df_production_status = df_simule[[
    "iot_statut_machine"
]].drop_duplicates(subset=[
        "iot_statut_machine",
    ]
)
df_production_status["id"] = df_production_status["iot_statut_machine"].astype("category").cat.codes + 1
df_production_status.head()
# Out:
#       iot_statut_machine  id
# 0             Production   4
# 4359               Panne   3
# 4360         Maintenance   2
# 14400    Arrêt Opérateur   1

# %%
df_plc.head()
# Out:
#   machine_id            timestamp iot_statut_machine  id_type_metal
# 0    MCH-001  2026-06-01 00:00:00         Production              2
# 1    MCH-002  2026-06-01 00:00:00         Production              2
# 2    MCH-007  2026-06-01 00:00:00         Production              2
# 3    MCH-004  2026-06-01 00:00:00         Production              4
# 4    MCH-006  2026-06-01 00:00:00         Production              1

# %%
df_plc = df_plc.merge(
    df_production_status[["iot_statut_machine", "id"]].rename(columns={"id": "id_status_production"}),
    on="iot_statut_machine",
    how="left"
).drop(columns="iot_statut_machine")
df_plc.head()
# Out:
#   machine_id            timestamp  id_type_metal  id_status_production
# 0    MCH-001  2026-06-01 00:00:00              2                     4
# 1    MCH-002  2026-06-01 00:00:00              2                     4
# 2    MCH-007  2026-06-01 00:00:00              2                     4
# 3    MCH-004  2026-06-01 00:00:00              4                     4
# 4    MCH-006  2026-06-01 00:00:00              1                     4

# %%
df_nominale = df_simule[["timestamp", "machine_id", "vitesse_rotation_nominal", "courant_moteur_nominal", "pression_hydraulique_nominal", "statut_nominal", "temp_base_moteur"]]

# %%
from utils import name_csv_file
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[17], line 2
#       1 df_labels = None
# ----> 2 from utils import name_csv_file
#
# ImportError: cannot import name 'name_csv_file' from 'utils' (/home/tux/Documents/M1_Epsi/MSPR2/send_datas_mqtt/src/gold/utils.py)

# %%
from utils import record_future_send_in_jsonl

folder_path = Path("../../datas/gold")
folder_path.mkdir(parents=True, exist_ok=True)
df_type_machine.to_csv(
    name_csv_file(
        folder_path=folder_path,
        filename="type_machine",
        extension=".csv",
        type_dst="postgres"
    ), index=False, encoding='utf-8'
)
df_type_metal.to_csv(
    name_csv_file(
        folder_path=folder_path,
        filename="type_metal",
        extension=".csv",
        type_dst="postgres"
    ), index=False, encoding='utf-8'
)
df_production_status.to_csv(
    name_csv_file(
        folder_path=folder_path,
        filename="production_status",
        extension=".csv",
        type_dst="postgres"
    ), index=False, encoding='utf-8'
)
df_nominale.to_csv(
    name_csv_file(
        folder_path=folder_path,
        filename="nominale_values",
        extension=".csv",
        type_dst="postgres"
    ), index=False, encoding='utf-8'
)

# %%
df_iot = (
    df_iot.sort_values("timestamp")
      .reset_index(drop=True)
)
df_plc = (
    df_plc.sort_values("timestamp")
      .reset_index(drop=True)
)
record_future_send_in_jsonl(df_iot, df_plc, output_path=r"../../datas/gold/mqtt_iot_plc_send.jsonl")
