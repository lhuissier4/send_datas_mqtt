# %%
import pandas as pd, numpy as np

# %%
df_simule = pd.read_csv(r"../../datas/bronze/dataset_brut.csv")

# %%
df_simule.head()
# Out:
#              timestamp machine_id type_machine secteur type_metal  \
# 0  2026-06-01 00:00:00    MCH-001   CNC_5_Axes    Aéro  Aluminium
# 1  2026-06-01 00:00:30    MCH-001   CNC_5_Axes    Aéro  Aluminium
# 2  2026-06-01 00:01:00    MCH-001   CNC_5_Axes    Aéro  Aluminium
# 3  2026-06-01 00:01:30    MCH-001   CNC_5_Axes    Aéro  Aluminium
# 4  2026-06-01 00:02:00    MCH-001   CNC_5_Axes    Aéro  Aluminium
#
#    vitesse_rotation_nominal  courant_moteur_nominal  \
# 0                      6000                    20.0
# 1                      6000                    20.0
# 2                      6000                    20.0
# 3                      6000                    20.0
# 4                      6000                    20.0
#
#    pression_hydraulique_nominal statut_nominal  temp_base_moteur  ...  \
# 0                           0.0     Production              40.0  ...
# 1                           0.0     Production              40.0  ...
# 2                           0.0     Production              40.0  ...
# 3                           0.0     Production              40.0  ...
# 4                           0.0     Production              40.0  ...
#
#   iot_vitesse_rotation iot_courant_moteur  iot_pression_hydraulique  \
# 0               6000.0          19.815780                  0.000000
# 1               6000.0          20.028414                  0.000000
# 2               6000.0          20.318093                  0.355548
# 3               6000.0          19.882224                  0.000000
# 4               6000.0          19.984053                  0.240067
#
#    iot_temperature  iot_vibration_rms  iot_vibration_peak  iot_charge_moteur  \
# 0        48.711109           0.856741            1.267143               45.0
# 1        48.552522           0.852020            1.355303               45.0
# 2        48.749168           0.849968            1.226547               45.0
# 3        48.968161           0.881784            1.205064               45.0
# 4        48.529023           0.837604            1.358074               45.0
#
#      age_jours  age_virtuel_jours  RUL_jours
# 0  1200.000000         840.000000   1.513542
# 1  1200.000347         840.000347   1.513194
# 2  1200.000694         840.000694   1.512847
# 3  1200.001042         840.001042   1.512500
# 4  1200.001389         840.001389   1.512153
#
# [5 rows x 22 columns]

# %%
df_simule.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1854720 entries, 0 to 1854719
# Data columns (total 22 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0   timestamp                     str
#  1   machine_id                    str
#  2   type_machine                  str
#  3   secteur                       str
#  4   type_metal                    str
#  5   vitesse_rotation_nominal      int64
#  6   courant_moteur_nominal        float64
#  7   pression_hydraulique_nominal  float64
#  8   statut_nominal                str
#  9   temp_base_moteur              float64
#  10  iot_statut_machine            str
#  11  label_gmao                    str
#  12  iot_vitesse_rotation          float64
#  13  iot_courant_moteur            float64
#  14  iot_pression_hydraulique      float64
#  15  iot_temperature               float64
#  16  iot_vibration_rms             float64
#  17  iot_vibration_peak            float64
#  18  iot_charge_moteur             float64
#  19  age_jours                     float64
#  20  age_virtuel_jours             float64
#  21  RUL_jours                     float64
# dtypes: float64(13), int64(1), str(8)
# memory usage: 311.3 MB

# %%
df_clean_iot = df_simule.drop(columns=[
    "age_jours",
    "age_virtuel_jours",
    "label_gmao",
    "RUL_jours",
    "secteur",
    "type_machine",
    "vitesse_rotation_nominal",
    "courant_moteur_nominal",
    "pression_hydraulique_nominal",
    "statut_nominal",
    "type_metal",
    "temp_base_moteur",
    "iot_statut_machine",
    "iot_vibration_rms"
])
df_clean_plc = df_simule[[
        "machine_id",
        "timestamp",
        "iot_statut_machine",
        "type_metal", # TODO: mettre un id et non un str
]]

# %%
df_clean_iot["timestamp"] = pd.to_datetime(
    df_clean_iot["timestamp"],
    format="%Y-%m-%d %H:%M:%S"
)
df_clean_plc["timestamp"] = pd.to_datetime(
    df_clean_plc["timestamp"],
    format="%Y-%m-%d %H:%M:%S"
)
df_clean_iot.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1854720 entries, 0 to 1854719
# Data columns (total 8 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   timestamp                 datetime64[us]
#  1   machine_id                str
#  2   iot_vitesse_rotation      float64
#  3   iot_courant_moteur        float64
#  4   iot_pression_hydraulique  float64
#  5   iot_temperature           float64
#  6   iot_vibration_peak        float64
#  7   iot_charge_moteur         float64
# dtypes: datetime64[us](1), float64(6), str(1)
# memory usage: 113.2 MB

# %%
df_clean_iot = (
    df_clean_iot.sort_values("timestamp")
      .reset_index(drop=True)
)
df_clean_plc = (
    df_clean_plc.sort_values("timestamp")
      .reset_index(drop=True)
)

# %%
pd.set_option("display.max_colwidth", None)
df_clean_iot.head(50)
# Out:
#              timestamp machine_id  iot_vitesse_rotation  iot_courant_moteur  \
# 0  2026-06-01 00:00:00    MCH-001                6000.0           19.815780
# 1  2026-06-01 00:00:00    MCH-002                4500.0           22.085784
# 2  2026-06-01 00:00:00    MCH-007                4800.0           16.279980
# 3  2026-06-01 00:00:00    MCH-004                1250.0           43.193466
# 4  2026-06-01 00:00:00    MCH-006                   0.0           54.966129
# 5  2026-06-01 00:00:00    MCH-005                4300.0           24.147071
# 6  2026-06-01 00:00:00    MCH-003                5000.0           14.950068
# 7  2026-06-01 00:00:30    MCH-007                4800.0           15.856575
# 8  2026-06-01 00:00:30    MCH-006                   0.0           55.047077
# 9  2026-06-01 00:00:30    MCH-002                4500.0           21.962499
# 10 2026-06-01 00:00:30    MCH-003                5000.0           14.853642
# 11 2026-06-01 00:00:30    MCH-004                1250.0           43.183121
# 12 2026-06-01 00:00:30    MCH-001                6000.0           20.028414
# 13 2026-06-01 00:00:30    MCH-005                4300.0           24.030777
# 14 2026-06-01 00:01:00    MCH-003                5000.0           14.951349
# 15 2026-06-01 00:01:00    MCH-005                4300.0           24.262574
# 16 2026-06-01 00:01:00    MCH-006                   0.0           54.715036
# 17 2026-06-01 00:01:00    MCH-004                1250.0           42.738793
# 18 2026-06-01 00:01:00    MCH-007                4800.0           15.776861
# 18                  0.000000        39.427705            0.641741
# 19                  0.355548        48.749168            1.226547
# 20                       NaN              NaN                 NaN
# 21                180.267872        61.494915            3.259590
# 22                  0.000000        39.083549            0.679370
# 23                  0.128085        40.506735            0.658770
# 24                  0.000000        42.890956            1.466154
# 25                  0.000000        48.968161            1.205064
# 26                  0.000000        41.278648            1.347563
# 27                  0.000000        55.468432            0.998972
# 28                  0.549461        38.722895            0.568212
# 29                  0.000000        40.915055            0.630287
# 30                  0.000000        42.421547            1.330698
# 31                  0.407042        40.656471            1.321940
# 32                  0.000000        56.341328            1.090652
# 33                179.595862        61.628328            3.212131
# 34                  0.240067        48.529023            1.358074
# 35                  0.290524        56.375214            1.077081
# 36                  0.000000        39.790938            0.613498
# 37                  0.000000        40.621054            0.612538
# 38                  0.000000        40.943777            1.321292
# 39                  0.175664        48.529185            1.189434
# 40                179.532486        61.056342            3.108680
# 41                  0.000000        42.812413            1.460647
# 42                       NaN              NaN                 NaN
# 43                       NaN              NaN                 NaN
# 44                  0.000000        41.328336            1.355779
# 45                  0.267906        40.590039            0.651652
# 46                  0.817103        48.982680            1.104430
# 47                  0.082954        39.001713            0.639967
# 48                180.430537        61.544510            3.088367
# 49                  0.000000        41.042724            0.652621
#
#     iot_charge_moteur
# 0                45.0
# 1                45.0
# 2                45.0
# 3                80.0
# 4                70.0
# 5                45.0
# 6                45.0
# 7                45.0
# 8                70.0
# 9                45.0
# 10               45.0
# 11               80.0
# 12               45.0
# 13               45.0
# 14               45.0
# 15               45.0
# 16               70.0
# 17               80.0
# 18               45.0
# 19               45.0
# 20                NaN
# 21               70.0
# 22               45.0
# 23               45.0
# 24               45.0
# 25               45.0
# 26               45.0
# 27               80.0
# 28               45.0
# 29               45.0
# 30               45.0
# 31               45.0
# 32               80.0
# 33               70.0
# 34               45.0
# 35               80.0
# 36               45.0
# 37               45.0
# 38               45.0
# 39               45.0
# 40               70.0
# 41               45.0
# 42                NaN
# 43                NaN
# 44               45.0
# 45               45.0
# 46               45.0
# 47               45.0
# 48               70.0
# 49               45.0

# %%
df_clean_plc.head(50)  # TODO: mettre un numéro à iot_statut_machine
# Out:
#    machine_id           timestamp iot_statut_machine type_metal
# 0     MCH-001 2026-06-01 00:00:00         Production  Aluminium
# 1     MCH-002 2026-06-01 00:00:00         Production  Aluminium
# 2     MCH-007 2026-06-01 00:00:00         Production  Aluminium
# 3     MCH-004 2026-06-01 00:00:00         Production     Titane
# 4     MCH-006 2026-06-01 00:00:00         Production      Acier
# 5     MCH-005 2026-06-01 00:00:00         Production  Aluminium
# 6     MCH-003 2026-06-01 00:00:00         Production  Aluminium
# 7     MCH-007 2026-06-01 00:00:30         Production  Aluminium
# 8     MCH-006 2026-06-01 00:00:30         Production      Acier
# 9     MCH-002 2026-06-01 00:00:30         Production  Aluminium
# 10    MCH-003 2026-06-01 00:00:30         Production  Aluminium
# 11    MCH-004 2026-06-01 00:00:30         Production     Titane
# 12    MCH-001 2026-06-01 00:00:30         Production  Aluminium
# 13    MCH-005 2026-06-01 00:00:30         Production  Aluminium
# 14    MCH-003 2026-06-01 00:01:00         Production  Aluminium
# 15    MCH-005 2026-06-01 00:01:00         Production  Aluminium
# 16    MCH-006 2026-06-01 00:01:00         Production      Acier
# 17    MCH-004 2026-06-01 00:01:00         Production     Titane
# 18    MCH-007 2026-06-01 00:01:00         Production  Aluminium
# 19    MCH-001 2026-06-01 00:01:00         Production  Aluminium
# 20    MCH-002 2026-06-01 00:01:00         Production  Aluminium
# 21    MCH-006 2026-06-01 00:01:30         Production      Acier
# 22    MCH-007 2026-06-01 00:01:30         Production  Aluminium
# 23    MCH-003 2026-06-01 00:01:30         Production  Aluminium
# 24    MCH-005 2026-06-01 00:01:30         Production  Aluminium
# 25    MCH-001 2026-06-01 00:01:30         Production  Aluminium
# 26    MCH-002 2026-06-01 00:01:30         Production  Aluminium
# 27    MCH-004 2026-06-01 00:01:30         Production     Titane
# 28    MCH-007 2026-06-01 00:02:00         Production  Aluminium
# 29    MCH-003 2026-06-01 00:02:00         Production  Aluminium
# 30    MCH-005 2026-06-01 00:02:00         Production  Aluminium
# 31    MCH-002 2026-06-01 00:02:00         Production  Aluminium
# 32    MCH-004 2026-06-01 00:02:00         Production     Titane
# 33    MCH-006 2026-06-01 00:02:00         Production      Acier
# 34    MCH-001 2026-06-01 00:02:00         Production  Aluminium
# 35    MCH-004 2026-06-01 00:02:30         Production     Titane
# 36    MCH-007 2026-06-01 00:02:30         Production  Aluminium
# 37    MCH-003 2026-06-01 00:02:30         Production  Aluminium
# 38    MCH-002 2026-06-01 00:02:30         Production  Aluminium
# 39    MCH-001 2026-06-01 00:02:30         Production  Aluminium
# 40    MCH-006 2026-06-01 00:02:30         Production      Acier
# 41    MCH-005 2026-06-01 00:02:30         Production  Aluminium
# 42    MCH-005 2026-06-01 00:03:00         Production  Aluminium
# 43    MCH-004 2026-06-01 00:03:00         Production     Titane
# 44    MCH-002 2026-06-01 00:03:00         Production  Aluminium
# 45    MCH-003 2026-06-01 00:03:00         Production  Aluminium
# 46    MCH-001 2026-06-01 00:03:00         Production  Aluminium
# 47    MCH-007 2026-06-01 00:03:00         Production  Aluminium
# 48    MCH-006 2026-06-01 00:03:00         Production      Acier
# 49    MCH-003 2026-06-01 00:03:30         Production  Aluminium

# %%
df_clean_iot.to_csv(r"../../datas/silver/dataset_iot.csv", index=False, encoding='utf-8')
df_clean_plc.to_csv(r"../../datas/silver/dataset_plc.csv", index=False, encoding='utf-8')
